# %% [markdown]
# # 💜 RUPSHA Launcher
# Click **Runtime** → **Run all** to start RUPSHA!

# %%
# Step 1: Mount Google Drive (for saving memories)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Step 2: Install required packages
# !pip install gradio groq python-dotenv -q

# %%
# Step 3: Clone the RUPSHA code from GitHub
# REPLACE 'YOUR_USERNAME' with your actual GitHub username
# !git clone https://github.com/Mickey-11-sys/rupsha-ai.git
# %cd rupsha-ai

# %%
# Step 4: Set your API key
import os
from google.colab import userdata

# Try to get key from Colab Secrets (safest way)
try:
    os.environ['GROQ_API_KEY'] = userdata.get('GROQ_API_KEY')
    print('✅ Key loaded from Colab Secrets!')
except:
    # If no secret saved, paste it here (not recommended for sharing)
    os.environ['GROQ_API_KEY'] = 'gsk_your_key_here'
    print('⚠️ Using hardcoded key. Use Colab Secrets for safety.')

os.environ['USER_NAME'] = 'Friend'  # Change to your name

# %%
# Step 5: Launch RUPSHA!
# !python app.py
